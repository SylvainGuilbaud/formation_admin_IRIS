# %% [markdown]
# # Connect to FHIR SQL Builder

# %%
import intersystems_iris as iris

# %% [markdown]
# ## Create the dbapi connection

# %%
# create the dbapi connection

host = "iris-prod-2"
port = 1972
namespace = "IRISAPP"
user = "SuperUser"
password = "SYS"

conn = iris.connect(
                    hostname=host, 
                    port=port, 
                    namespace=namespace, 
                    username=user, 
                    password=password
                   )

# create a cursor
cur = conn.cursor()

# %% [markdown]
# ## Create the DriverLicense Table

# %%
# execute a query
cur.execute("""create TABLE if not exists AB.DriverLicense (

    Code varchar(255) not null,
    Valide TINYINT not null

)""")
# Out:
# 0

# %% [markdown]
# ## Insert New Data

# %%
cur.execute("""delete AB.DriverLicense""")
# Out:
# 0

# %%
cur.execute("""INSERT INTO AB.DriverLicense (Code, Valide) VALUES ('S99916528', 1)""")
cur.execute("""INSERT into AB.DriverLicense (Code, Valide) VALUES ('S99950276', 0)""")
# Out:
# 1

# %% [markdown]
# ## Check new data

# %%
cur.execute("select * from AB.DriverLicense")
cur.fetchall()
# Out:
# [Row(Code='S99916528', Valide=1), Row(Code='S99950276', Valide=0)]

# %% [markdown]
# ## Create a dataframe from patient table

# %%
import pandas as pd
# create an engine
from sqlalchemy import create_engine
engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)

sql = "select * from A1.Patient"

df = pd.read_sql(sql, engine)

print(df)

# transform the data to csv
df.to_csv("patients.csv")
# Out:
# /tmp/ipykernel_27651/583300264.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, engine)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 8
#       4 engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)
#       6 sql = "select * from A1.Patient"
# ----> 8 df = pd.read_sql(sql, engine)
#      10 print(df)
#      12 # transform the data to csv
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)
#    2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:2700, in SQLiteDatabase.execute(self, sql, params)
#    2698     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2699 args = [] if params is None else [params]
# -> 2700 cur = self.con.cursor()
#    2701 try:
#    2702     cur.execute(sql, *args)
#
# AttributeError: 'Engine' object has no attribute 'cursor'

# %%
import pandas as pd
# create an engine
from sqlalchemy import create_engine
engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)

sql = "select * from A1.Patient"

df = pd.read_sql(sql, engine)

print(df)

# transform the data to csv
df.to_csv("patients.csv")

# %%
engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)
sql = "SELECT id, lastname, firstname, dob, sex FROM app.personne"
df = pd.read_sql(sql, engine)

print(df)
# Out:
# /tmp/ipykernel_27651/2151928839.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, engine)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)
#       2 sql = "SELECT id, lastname, firstname, dob, sex FROM app.personne"
# ----> 3 df = pd.read_sql(sql, engine)
#       5 print(df)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)
#    2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:2700, in SQLiteDatabase.execute(self, sql, params)
#    2698     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2699 args = [] if params is None else [params]
# -> 2700 cur = self.con.cursor()
#    2701 try:
#    2702     cur.execute(sql, *args)
#
# AttributeError: 'Engine' object has no attribute 'cursor'

# %%
sql = "insert into app.personne (id,lastname,firstname) values (7,'ggg',kkk')
# Out:
#   Cell In[13], line 1
#     sql = "insert into app.personne (id,lastname,firstname) values (7,'ggg',kkk')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
conn.close()

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)

sql = "select id from app.personne"

df = pd.read_sql(sql, engine)

print(df)
# Out:
# /tmp/ipykernel_27651/2484452095.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, engine)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 8
#       4 engine = create_engine('iris://' + user + ':' + password + '@' + host + ':' + str(port) + '/' + namespace)
#       6 sql = "select id from app.personne"
# ----> 8 df = pd.read_sql(sql, engine)
#      10 print(df)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)
#    2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File /opt/conda/lib/python3.11/site-packages/pandas/io/sql.py:2700, in SQLiteDatabase.execute(self, sql, params)
#    2698     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2699 args = [] if params is None else [params]
# -> 2700 cur = self.con.cursor()
#    2701 try:
#    2702     cur.execute(sql, *args)
#
# AttributeError: 'Engine' object has no attribute 'cursor'
